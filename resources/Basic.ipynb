# %%
1+2
# Out:
# OUT: BOOOM!!
# ERROR: Crash!!
# <<137, 80, 78, 71, 13, 10, 26, 10, 0, 0, 0, 13, 73, 72, 68, 82, 0, 0, 0, 227, 0, 0, 0, 95, 8, 6, 0, 0, 0, 26, 134, 112, 66, 0, 0, 32, 41, 73, 68, 65, 84, 120, 218, 236, 157, 91, 115, 91, 215, 125, ...>>
